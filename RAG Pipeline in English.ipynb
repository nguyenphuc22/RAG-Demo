# %%
# !pip install -q datasets pymongo sentence_transformers
# !pip install pymongo[srv]
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# zsh:1: no matches found: pymongo[srv]

# %%
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown


def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
# Used to securely store your API key
# from google.colab import userdata

# %%
model = genai.GenerativeModel('gemini-1.5-pro')

# %%
genai.configure(api_key=("API_KEY")) # Replace with your API key. Cái này key này free ngon lắm. tự tạo nhé :D

# %%
import pymongo
import pandas as pd

# %%
# @title Step 1: Connect to MongoDB
client = pymongo.MongoClient('mongodb+srv://phuc:pBWtKzGm3jHnMxsr@cluster0.llq9qnt.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0')  # Update with your MongoDB connection string

# %%
db = client["sample_mflix"]  # Replace with your database name
collection = db['embedding_for_vector_search']

# %%
# Step 2: Retrieve data from MongoDB
data = list(collection.find())

# Step 3: Convert data to Pandas DataFrame
df = pd.DataFrame(data)
df.head()
# Out:
#                         _id  \
# 0  66adb90dea517c733889aee1
# 1  66adb90dea517c733889aee2
# 2  66adb90dea517c733889aee3
# 3  66adb90dea517c733889aee4
# 4  66adb90dea517c733889aee5
#
#                                                 name     shortDescription  \
# 0  AT&T Apple iPhone 11, 64GB, Black - Prepaid Sm...                  NaN
# 1  Cricket Wireless Moto G Stylus 2023, 128GB, 4G...                  NaN
# 2  AT&T Samsung Galaxy A14 5G, 64GB Black - Prepa...                  NaN
# 3  AT&T Samsung Galaxy A15 5G, 128GB, 4GB RAM, Bl...                  NaN
# 4  AT&T Samsung Galaxy A14 5G, 64GB Black - Prepa...  Samsung Merchandise
#
#                                         thumbnailUrl  \
# 0  https://i5.walmartimages.com/seo/AT-T-Apple-iP...
# 1  https://i5.walmartimages.com/seo/Cricket-Wirel...
# 2  https://i5.walmartimages.com/seo/AT-T-Samsung-...
# 3  https://i5.walmartimages.com/seo/AT-T-Samsung-...
# 4  https://i5.walmartimages.com/asr/fd28fe01-1f35...
#
# ...

# %% [markdown]
# Gemini

# %%
def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
from sentence_transformers import SentenceTransformer
embedding_model = SentenceTransformer("sentence-transformers/all-MiniLM-L12-v2")
def get_embedding(text: str) -> list[float]:
    if not text.strip():
        print("Attempted to get embedding for empty text.")
        return []

    embedding = embedding_model.encode(text)

    return embedding.tolist()
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/615 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/352 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
get_embedding("Ngoc is speaking good?")
# Out:
# [-0.037697695195674896,
#  -0.03497321903705597,
#  -0.052854303270578384,
#  0.03642655164003372,
#  -0.01528235524892807,
#  0.05169946700334549,
#  -0.0318610779941082,
#  -0.045586202293634415,
#  -0.030457627028226852,
#  0.01305920910090208,
#  -0.018955135717988014,
#  -0.029496407136321068,
#  -0.0009052400127984583,
#  -0.008757018484175205,
#  0.06773227453231812,
#  0.0532524473965168,
#  0.10341642051935196,
#  -0.04594891145825386,
#  -0.015477851964533329,
#  -0.019960952922701836,
#  -0.07178784906864166,
#  0.04317556321620941,
#  0.0035045684780925512,
#  -0.0330507829785347,
#  0.05767841264605522,
#  0.021095914766192436,
#  -0.022251879796385765,
#  -0.06728392839431763,
#  0.12880119681358337,
#  0.029916835948824883,
#  -0.03775082901120186,
#  0.0482512004673481,
#  0.009074910543859005,
#  0.08388448506593704,
#  -0.067924365401268,
#  0.06600961834192276,
#  -0.038427866995334625,
#  0.012010916136205196,
#  -0.013895553536713123,
#  0.024183763191103935,
# ...

# %%
len(get_embedding("Ngoc is speaking good?"))
# Out:
# 384

# %%
def vector_search(user_query, collection, limit=4):
    """
    Perform a vector search in the MongoDB collection based on the user query.

    Args:
    user_query (str): The user's query string.
    collection (MongoCollection): The MongoDB collection to search.

    Returns:
    list: A list of matching documents.
    """

    # Generate embedding for the user query
    query_embedding = get_embedding(user_query)

    if query_embedding is None:
        return "Invalid query or embedding generation failed."

    # Define the vector search pipeline
    vector_search_stage = {
        "$vectorSearch": {
            "index": "vector_index",
            "queryVector": query_embedding,
            "path": "embedding",
            "numCandidates": 400,
            "limit": limit,
        }
    }

    unset_stage = {
        "$unset": "embedding"
    }

    project_stage = {
        "$project": {
            "_id": 0,
            "name": 1,
            "description": 1,
            "price": 1,
            "rating": 1,
            "score": {
                "$meta": "vectorSearchScore"
            }
        }
    }

    pipeline = [vector_search_stage, unset_stage, project_stage]

    # Execute the search
    results = collection.aggregate(pipeline)

    return list(results)

# %%
def get_search_result(query, collection):
    get_knowledge = vector_search(query, collection, 10)
    search_result = ""
    i = 0
    for result in get_knowledge:
        print(result)
        if result.get('name'):
            i += 1
            search_result += f"\n {i}) Name: {result.get('name')}"

            if result.get('price'):
                search_result += f", Price: {result.get('price')}"
            else:
                # Mock up data
                # Retrieval model pricing from the internet.
                search_result += f", Price: Contact for more information"

            if result.get('rating'):
                search_result += f", Rating: {result.get('rating')}"

    return search_result

# %%
# Conduct query with retrival of sources
query = "please give me price of Samsung Galaxy 5G, 4G! Why i should by this?"
source_information = get_search_result(query.lower(), collection)
source_information
# Out:
# ''

# %%
combined_information = f"Become a sales consultant for a phone store. Customer's question: {query}\nAnswer the question based on the following product information: {source_information}."
print('==== LLMs Inference')
print(combined_information)
# Out:
# ==== LLMs Inference
# Become a sales consultant for a phone store. Customer's question: please give me price of Samsung Galaxy 5G, 4G! Why i should by this?
# Answer the question based on the following product information: .

# %%
# %%time
response = model.generate_content(combined_information)
to_markdown(response.text)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1722781829.914450  367032 check_gcp_environment_no_op.cc:29] ALTS: Platforms other than Linux and Windows are not supported
# CPU times: user 16.4 ms, sys: 12.9 ms, total: 29.4 ms
# Wall time: 3.71 s
# > Please provide me with the product information so I can answer your question! I need to know the specifics about the Samsung Galaxy 5G and 4G phones you're interested in, such as:
# >
# > * **Specific model:**  Are you looking at the Galaxy S23, A54, or another model?
# > * **Storage size:**  Do you need 64GB, 128GB, or more?
# > * **Carrier deals:** Are you planning to buy your phone outright, or are you interested in carrier plans and promotions?
# >
# > Once you provide me with these details, I can give you accurate pricing information and highlight the best reasons why a Samsung Galaxy phone might be perfect for you! 😊
